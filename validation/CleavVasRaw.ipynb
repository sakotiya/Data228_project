# %% [markdown]
# # Clean vs Raw Summary
#
# This notebook compares all RAW vs CLEANED parquet files and produces a compact tabular summary:
#
# File, Raw Rows, Clean Rows, Raw - Clean, cleaned %, removed %, Raw Cols, Clean Cols, Dropped Cols, Added Cols, Major Null Reduction.
#
# Run cells from top to bottom.

# %%
import pandas as pd
from pathlib import Path

RAW_DATA_DIR = "/Users/vidushi/Documents/bubu/Raw_data/raw_data"
CLEANED_DATA_DIR = "/Users/vidushi/Documents/bubu/cleaned_data"

print("RAW_DATA_DIR:", RAW_DATA_DIR)
print("CLEANED_DATA_DIR:", CLEANED_DATA_DIR)
# Out:
# RAW_DATA_DIR: /Users/vidushi/Documents/bubu/Raw_data/raw_data
# CLEANED_DATA_DIR: /Users/vidushi/Documents/bubu/cleaned_data

# %%
# Helper functions (with safe parquet reader) and file listing

import pyarrow.parquet as pq


def safe_read_parquet(path: Path) -> pd.DataFrame:
    """Read parquet file with timestamp overflow handling (same logic as other notebooks)."""
    try:
        # Fast path: normal pandas reader
        return pd.read_parquet(path)
    except Exception as e:
        error_type = type(e).__name__
        try:
            msg = str(e)
        except Exception:
            msg = ""

        is_ts_error = (
            'ArrowInvalid' in error_type or
            'out of bounds' in msg.lower() or
            'timestamp' in msg.lower() or
            'casting' in msg.lower()
        )

        if not is_ts_error:
            # Not a timestamp problem, re-raise
            raise

        print(f"    ⚠️  Timestamp issue for {path.name}, using safe mode...")
        table = pq.read_table(path)
        df = table.to_pandas(timestamp_as_object=True)

        # Try to convert obvious datetime-like columns back to datetime
        for col in df.columns:
            if df[col].dtype == 'object' and any(x in col.lower() for x in ['time', 'datetime', 'date']):
                try:
                    df[col] = pd.to_datetime(df[col], errors='coerce')
                except Exception:
                    pass
        return df


def get_parquet_files(directory: str):
    base = Path(directory)
    return {p.name: p for p in base.glob("*.parquet")}


raw_files = get_parquet_files(RAW_DATA_DIR)
clean_files = get_parquet_files(CLEANED_DATA_DIR)

common_names = sorted(set(raw_files.keys()) & set(clean_files.keys()))
print(f"Found {len(common_names)} files present in both RAW and CLEANED.")
# Out:
# Found 100 files present in both RAW and CLEANED.

# %%
# Build compact summary table

summary_rows = []

print("\n================ CLEAN vs RAW SUMMARY ================")
print(f"Total common files: {len(common_names)}")

for idx, name in enumerate(common_names, 1):
    raw_path = raw_files[name]
    clean_path = clean_files[name]

    print(f"\n[{idx}/{len(common_names)}] {name}")
    print(f"  Raw path   : {raw_path}")
    print(f"  Clean path : {clean_path}")

    try:
        df_raw = safe_read_parquet(raw_path)
        df_clean = safe_read_parquet(clean_path)

        raw_rows = len(df_raw)
        clean_rows = len(df_clean)
        raw_cols = len(df_raw.columns)
        clean_cols = len(df_clean.columns)

        print(f"  Raw rows   : {raw_rows:,}, cols: {raw_cols}")
        print(f"  Clean rows : {clean_rows:,}, cols: {clean_cols}")

        # Row stats
        diff_rows = raw_rows - clean_rows
        cleaned_pct = (clean_rows / raw_rows * 100) if raw_rows > 0 else 0
        removed_pct = (diff_rows / raw_rows * 100) if raw_rows > 0 else 0

        print(f"  Rows removed: {diff_rows:,} ({removed_pct:.2f}% removed, {cleaned_pct:.2f}% kept)")

        # Column stats
        raw_cols_set = set(df_raw.columns)
        clean_cols_set = set(df_clean.columns)
        dropped_cols = sorted(raw_cols_set - clean_cols_set)
        added_cols = sorted(clean_cols_set - raw_cols_set)

        if dropped_cols:
            print(f"  Dropped cols: {', '.join(dropped_cols)}")
        if added_cols:
            print(f"  Added cols  : {', '.join(added_cols)}")

        # Major null reduction flag (True if total nulls reduced by > 50%)
        raw_nulls = df_raw.isnull().sum().sum()
        clean_nulls = df_clean.isnull().sum().sum()
        major_null_reduction = False
        reduction = 0.0
        if raw_nulls > 0:
            reduction = (raw_nulls - clean_nulls) / raw_nulls * 100
            major_null_reduction = reduction >= 50

        print(f"  Nulls raw   : {raw_nulls:,}")
        print(f"  Nulls clean : {clean_nulls:,}")
        print(f"  Null reduction: {reduction:.2f}%  (major={major_null_reduction})")

        summary_rows.append({
            "File": name,
            "Raw Rows": raw_rows,
            "Clean Rows": clean_rows,
            "Raw - Clean": diff_rows,
            "cleaned %": round(cleaned_pct, 2),
            "removed %": round(removed_pct, 2),
            "Raw Cols": raw_cols,
            "Clean Cols": clean_cols,
            "Dropped Cols": ", ".join(dropped_cols) if dropped_cols else "",
            "Added Cols": ", ".join(added_cols) if added_cols else "",
            "Major Null Reduction": major_null_reduction,
        })

    except Exception as e:
        print(f"  ❌ ERROR comparing {name}: {e}")

summary_df = pd.DataFrame(summary_rows)
print("\nSummary (first 10 files):")
display(summary_df.head(10))
# Out:
# ================ CLEAN vs RAW SUMMARY ================
# Total common files: 100
#
# [1/100] fhv_tripdata_2015-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2015-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2015-02.parquet
#   Raw rows   : 3,053,183, cols: 7
#   Clean rows : 3,053,183, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 6,577,667
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [2/100] fhv_tripdata_2015-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2015-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2015-12.parquet
#   Raw rows   : 8,888,809, cols: 7
#   Clean rows : 8,888,809, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 20,515,852
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [3/100] fhv_tripdata_2019-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2019-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2019-02.parquet
#     ⚠️  Timestamp issue for fhv_tripdata_2019-02.parquet, using safe mode...
#   Raw rows   : 1,707,650, cols: 7
#   Clean rows : 1,707,650, cols: 7
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 1,714,750
#   Nulls clean : 1,714,748
#   Null reduction: 0.00%  (major=False)
#
# [4/100] fhv_tripdata_2019-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2019-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2019-12.parquet
#   Raw rows   : 2,044,196, cols: 7
#   Clean rows : 2,044,196, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 2,113,294
#   Nulls clean : 13,805
#   Null reduction: 99.35%  (major=True)
#
# [5/100] fhv_tripdata_2024-01.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-01.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-01.parquet
#   Raw rows   : 1,290,116, cols: 7
#   Clean rows : 1,290,116, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 2,488,477
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [6/100] fhv_tripdata_2024-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-02.parquet
#   Raw rows   : 1,176,093, cols: 7
#   Clean rows : 1,176,093, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 2,304,513
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [7/100] fhv_tripdata_2024-03.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-03.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-03.parquet
#   Raw rows   : 1,469,352, cols: 7
#   Clean rows : 1,469,352, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 2,867,720
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [8/100] fhv_tripdata_2024-04.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-04.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-04.parquet
#   Raw rows   : 1,444,626, cols: 7
#   Clean rows : 1,444,626, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 2,706,403
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [9/100] fhv_tripdata_2024-05.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-05.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-05.parquet
#   Raw rows   : 1,352,502, cols: 7
#   Clean rows : 1,352,502, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 2,623,511
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [10/100] fhv_tripdata_2024-06.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-06.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-06.parquet
#   Raw rows   : 1,386,539, cols: 7
#   Clean rows : 1,386,539, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 2,643,442
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [11/100] fhv_tripdata_2024-07.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-07.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-07.parquet
#   Raw rows   : 1,382,739, cols: 7
#   Clean rows : 1,382,739, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 2,607,704
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [12/100] fhv_tripdata_2024-08.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-08.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-08.parquet
#   Raw rows   : 1,484,471, cols: 7
#   Clean rows : 1,484,471, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 3,021,337
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [13/100] fhv_tripdata_2024-09.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-09.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-09.parquet
#   Raw rows   : 1,718,375, cols: 7
#   Clean rows : 1,718,375, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 3,359,468
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [14/100] fhv_tripdata_2024-10.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-10.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-10.parquet
#   Raw rows   : 1,421,231, cols: 7
#   Clean rows : 1,421,231, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 2,860,098
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [15/100] fhv_tripdata_2024-11.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-11.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-11.parquet
#   Raw rows   : 1,591,082, cols: 7
#   Clean rows : 1,591,082, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 3,168,278
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [16/100] fhv_tripdata_2024-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2024-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2024-12.parquet
#   Raw rows   : 1,913,200, cols: 7
#   Clean rows : 1,913,200, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 3,910,552
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [17/100] fhv_tripdata_2025-01.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2025-01.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2025-01.parquet
#   Raw rows   : 1,898,108, cols: 7
#   Clean rows : 1,898,108, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 3,780,412
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [18/100] fhv_tripdata_2025-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2025-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2025-02.parquet
#   Raw rows   : 1,578,722, cols: 7
#   Clean rows : 1,578,722, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 3,108,664
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [19/100] fhv_tripdata_2025-03.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2025-03.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2025-03.parquet
#   Raw rows   : 2,182,992, cols: 7
#   Clean rows : 2,182,992, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 4,496,235
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [20/100] fhv_tripdata_2025-04.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2025-04.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2025-04.parquet
#   Raw rows   : 1,699,478, cols: 7
#   Clean rows : 1,699,478, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 3,311,979
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [21/100] fhv_tripdata_2025-05.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2025-05.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2025-05.parquet
#   Raw rows   : 2,210,721, cols: 7
#   Clean rows : 2,210,721, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 4,358,470
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [22/100] fhv_tripdata_2025-06.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2025-06.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2025-06.parquet
#   Raw rows   : 2,231,731, cols: 7
#   Clean rows : 2,231,731, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 4,377,477
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [23/100] fhv_tripdata_2025-07.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2025-07.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2025-07.parquet
#   Raw rows   : 2,187,536, cols: 7
#   Clean rows : 2,187,536, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 4,328,511
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [24/100] fhv_tripdata_2025-08.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhv_tripdata_2025-08.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhv_tripdata_2025-08.parquet
#   Raw rows   : 2,256,854, cols: 7
#   Clean rows : 2,256,854, cols: 6
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: SR_Flag
#   Nulls raw   : 4,537,566
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [25/100] fhvhv_tripdata_2019-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2019-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2019-02.parquet
#   Raw rows   : 20,159,102, cols: 24
#   Clean rows : 20,159,102, cols: 22
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: airport_fee, wav_match_flag
#   Nulls raw   : 53,269,785
#   Nulls clean : 12,438,540
#   Null reduction: 76.65%  (major=True)
#
# [26/100] fhvhv_tripdata_2019-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2019-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2019-12.parquet
#   Raw rows   : 22,243,901, cols: 24
#   Clean rows : 22,243,901, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 34,511,805
#   Nulls clean : 12,268,026
#   Null reduction: 64.45%  (major=True)
#
# [27/100] fhvhv_tripdata_2024-01.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-01.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-01.parquet
#   Raw rows   : 19,663,930, cols: 24
#   Clean rows : 19,663,930, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 10,437,474
#   Nulls clean : 10,437,474
#   Null reduction: 0.00%  (major=False)
#
# [28/100] fhvhv_tripdata_2024-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-02.parquet
#   Raw rows   : 19,359,148, cols: 24
#   Clean rows : 19,359,148, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 9,873,774
#   Nulls clean : 9,873,774
#   Null reduction: 0.00%  (major=False)
#
# [29/100] fhvhv_tripdata_2024-03.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-03.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-03.parquet
#   Raw rows   : 21,280,788, cols: 24
#   Clean rows : 21,280,788, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 11,284,158
#   Nulls clean : 11,284,158
#   Null reduction: 0.00%  (major=False)
#
# [30/100] fhvhv_tripdata_2024-04.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-04.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-04.parquet
#   Raw rows   : 19,733,038, cols: 24
#   Clean rows : 19,733,038, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 10,024,380
#   Nulls clean : 10,024,380
#   Null reduction: 0.00%  (major=False)
#
# [31/100] fhvhv_tripdata_2024-05.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-05.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-05.parquet
#   Raw rows   : 20,704,538, cols: 24
#   Clean rows : 20,704,538, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 10,294,946
#   Nulls clean : 10,294,946
#   Null reduction: 0.00%  (major=False)
#
# [32/100] fhvhv_tripdata_2024-06.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-06.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-06.parquet
#   Raw rows   : 20,123,226, cols: 24
#   Clean rows : 20,123,226, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 9,954,706
#   Nulls clean : 9,954,706
#   Null reduction: 0.00%  (major=False)
#
# [33/100] fhvhv_tripdata_2024-07.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-07.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-07.parquet
#   Raw rows   : 19,182,934, cols: 24
#   Clean rows : 19,182,934, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 9,672,892
#   Nulls clean : 9,672,892
#   Null reduction: 0.00%  (major=False)
#
# [34/100] fhvhv_tripdata_2024-08.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-08.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-08.parquet
#   Raw rows   : 19,128,392, cols: 24
#   Clean rows : 19,128,392, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 10,006,214
#   Nulls clean : 10,006,214
#   Null reduction: 0.00%  (major=False)
#
# [35/100] fhvhv_tripdata_2024-09.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-09.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-09.parquet
#   Raw rows   : 19,209,788, cols: 24
#   Clean rows : 19,209,788, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 9,143,748
#   Nulls clean : 9,143,748
#   Null reduction: 0.00%  (major=False)
#
# [36/100] fhvhv_tripdata_2024-10.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-10.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-10.parquet
#   Raw rows   : 20,028,282, cols: 24
#   Clean rows : 20,028,282, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 9,738,371
#   Nulls clean : 9,738,371
#   Null reduction: 0.00%  (major=False)
#
# [37/100] fhvhv_tripdata_2024-11.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-11.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-11.parquet
#   Raw rows   : 19,987,533, cols: 24
#   Clean rows : 19,987,533, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 9,692,933
#   Nulls clean : 9,692,933
#   Null reduction: 0.00%  (major=False)
#
# [38/100] fhvhv_tripdata_2024-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2024-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2024-12.parquet
#   Raw rows   : 21,068,851, cols: 24
#   Clean rows : 21,068,851, cols: 24
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 10,243,285
#   Nulls clean : 10,243,285
#   Null reduction: 0.00%  (major=False)
#
# [39/100] fhvhv_tripdata_2025-01.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2025-01.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2025-01.parquet
#   Raw rows   : 20,405,666, cols: 25
#   Clean rows : 20,405,666, cols: 25
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 10,070,270
#   Nulls clean : 10,070,270
#   Null reduction: 0.00%  (major=False)
#
# [40/100] fhvhv_tripdata_2025-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2025-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2025-02.parquet
#   Raw rows   : 19,339,461, cols: 25
#   Clean rows : 19,339,461, cols: 25
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 9,812,776
#   Nulls clean : 9,812,776
#   Null reduction: 0.00%  (major=False)
#
# [41/100] fhvhv_tripdata_2025-03.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2025-03.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2025-03.parquet
#   Raw rows   : 20,536,879, cols: 25
#   Clean rows : 20,536,879, cols: 25
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 6,901,913
#   Nulls clean : 6,901,913
#   Null reduction: 0.00%  (major=False)
#
# [42/100] fhvhv_tripdata_2025-04.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2025-04.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2025-04.parquet
#   Raw rows   : 19,753,983, cols: 25
#   Clean rows : 19,753,983, cols: 25
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 5,377,665
#   Nulls clean : 5,377,665
#   Null reduction: 0.00%  (major=False)
#
# [43/100] fhvhv_tripdata_2025-05.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2025-05.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2025-05.parquet
#   Raw rows   : 21,091,193, cols: 25
#   Clean rows : 21,091,193, cols: 25
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 6,034,550
#   Nulls clean : 6,034,550
#   Null reduction: 0.00%  (major=False)
#
# [44/100] fhvhv_tripdata_2025-06.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2025-06.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2025-06.parquet
#   Raw rows   : 19,868,009, cols: 25
#   Clean rows : 19,868,009, cols: 25
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 5,682,468
#   Nulls clean : 5,682,468
#   Null reduction: 0.00%  (major=False)
#
# [45/100] fhvhv_tripdata_2025-07.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2025-07.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2025-07.parquet
#   Raw rows   : 19,653,012, cols: 25
#   Clean rows : 19,653,012, cols: 25
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 5,492,276
#   Nulls clean : 5,492,276
#   Null reduction: 0.00%  (major=False)
#
# [46/100] fhvhv_tripdata_2025-08.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/fhvhv_tripdata_2025-08.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/fhvhv_tripdata_2025-08.parquet
#   Raw rows   : 19,271,461, cols: 25
#   Clean rows : 19,271,461, cols: 25
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Nulls raw   : 5,692,756
#   Nulls clean : 5,692,756
#   Null reduction: 0.00%  (major=False)
#
# [47/100] green_tripdata_2014-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2014-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2014-02.parquet
#   Raw rows   : 1,005,242, cols: 20
#   Clean rows : 1,004,969, cols: 17
#   Rows removed: 273 (0.03% removed, 99.97% kept)
#   Dropped cols: congestion_surcharge, ehail_fee, improvement_surcharge
#   Nulls raw   : 3,613,535
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [48/100] green_tripdata_2014-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2014-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2014-12.parquet
#   Raw rows   : 1,645,787, cols: 20
#   Clean rows : 1,643,114, cols: 18
#   Rows removed: 2,673 (0.16% removed, 99.84% kept)
#   Dropped cols: congestion_surcharge, ehail_fee
#   Nulls raw   : 3,291,605
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [49/100] green_tripdata_2015-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2015-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2015-02.parquet
#   Raw rows   : 1,574,830, cols: 20
#   Clean rows : 1,572,027, cols: 18
#   Rows removed: 2,803 (0.18% removed, 99.82% kept)
#   Dropped cols: congestion_surcharge, ehail_fee
#   Nulls raw   : 3,149,662
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [50/100] green_tripdata_2015-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2015-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2015-12.parquet
#   Raw rows   : 1,608,297, cols: 20
#   Clean rows : 1,604,779, cols: 18
#   Rows removed: 3,518 (0.22% removed, 99.78% kept)
#   Dropped cols: congestion_surcharge, ehail_fee
#   Nulls raw   : 3,216,596
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [51/100] green_tripdata_2019-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2019-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2019-02.parquet
#   Raw rows   : 615,594, cols: 20
#   Clean rows : 612,380, cols: 20
#   Rows removed: 3,214 (0.52% removed, 99.48% kept)
#   Nulls raw   : 858,444
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [52/100] green_tripdata_2019-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2019-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2019-12.parquet
#   Raw rows   : 455,294, cols: 20
#   Clean rows : 450,335, cols: 19
#   Rows removed: 4,959 (1.09% removed, 98.91% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 1,027,652
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [53/100] green_tripdata_2024-01.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-01.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-01.parquet
#   Raw rows   : 56,551, cols: 20
#   Clean rows : 55,809, cols: 19
#   Rows removed: 742 (1.31% removed, 98.69% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 77,044
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [54/100] green_tripdata_2024-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-02.parquet
#   Raw rows   : 53,577, cols: 20
#   Clean rows : 52,835, cols: 19
#   Rows removed: 742 (1.38% removed, 98.62% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 71,150
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [55/100] green_tripdata_2024-03.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-03.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-03.parquet
#   Raw rows   : 57,457, cols: 20
#   Clean rows : 56,681, cols: 19
#   Rows removed: 776 (1.35% removed, 98.65% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 70,046
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [56/100] green_tripdata_2024-04.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-04.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-04.parquet
#   Raw rows   : 56,471, cols: 20
#   Clean rows : 55,802, cols: 19
#   Rows removed: 669 (1.18% removed, 98.82% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 68,407
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [57/100] green_tripdata_2024-05.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-05.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-05.parquet
#   Raw rows   : 61,003, cols: 20
#   Clean rows : 60,208, cols: 19
#   Rows removed: 795 (1.30% removed, 98.70% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 72,369
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [58/100] green_tripdata_2024-06.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-06.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-06.parquet
#   Raw rows   : 54,748, cols: 20
#   Clean rows : 54,014, cols: 19
#   Rows removed: 734 (1.34% removed, 98.66% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 66,154
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [59/100] green_tripdata_2024-07.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-07.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-07.parquet
#   Raw rows   : 51,837, cols: 20
#   Clean rows : 51,123, cols: 19
#   Rows removed: 714 (1.38% removed, 98.62% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 61,501
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [60/100] green_tripdata_2024-08.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-08.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-08.parquet
#   Raw rows   : 51,771, cols: 20
#   Clean rows : 51,016, cols: 19
#   Rows removed: 755 (1.46% removed, 98.54% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 61,280
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [61/100] green_tripdata_2024-09.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-09.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-09.parquet
#   Raw rows   : 54,440, cols: 20
#   Clean rows : 53,678, cols: 19
#   Rows removed: 762 (1.40% removed, 98.60% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 64,667
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [62/100] green_tripdata_2024-10.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-10.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-10.parquet
#   Raw rows   : 56,147, cols: 20
#   Clean rows : 55,366, cols: 19
#   Rows removed: 781 (1.39% removed, 98.61% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 66,022
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [63/100] green_tripdata_2024-11.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-11.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-11.parquet
#   Raw rows   : 52,222, cols: 20
#   Clean rows : 51,377, cols: 19
#   Rows removed: 845 (1.62% removed, 98.38% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 61,742
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [64/100] green_tripdata_2024-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2024-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2024-12.parquet
#   Raw rows   : 53,994, cols: 20
#   Clean rows : 53,063, cols: 19
#   Rows removed: 931 (1.72% removed, 98.28% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 65,886
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [65/100] green_tripdata_2025-01.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2025-01.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2025-01.parquet
#   Raw rows   : 48,326, cols: 21
#   Clean rows : 47,506, cols: 20
#   Rows removed: 820 (1.70% removed, 98.30% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 61,185
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [66/100] green_tripdata_2025-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2025-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2025-02.parquet
#   Raw rows   : 46,621, cols: 21
#   Clean rows : 45,847, cols: 20
#   Rows removed: 774 (1.66% removed, 98.34% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 63,721
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [67/100] green_tripdata_2025-03.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2025-03.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2025-03.parquet
#   Raw rows   : 51,539, cols: 21
#   Clean rows : 50,756, cols: 20
#   Rows removed: 783 (1.52% removed, 98.48% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 72,840
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [68/100] green_tripdata_2025-04.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2025-04.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2025-04.parquet
#   Raw rows   : 52,132, cols: 21
#   Clean rows : 51,322, cols: 20
#   Rows removed: 810 (1.55% removed, 98.45% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 71,267
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [69/100] green_tripdata_2025-05.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2025-05.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2025-05.parquet
#   Raw rows   : 55,399, cols: 21
#   Clean rows : 54,441, cols: 20
#   Rows removed: 958 (1.73% removed, 98.27% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 74,867
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [70/100] green_tripdata_2025-06.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2025-06.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2025-06.parquet
#   Raw rows   : 49,390, cols: 21
#   Clean rows : 48,352, cols: 20
#   Rows removed: 1,038 (2.10% removed, 97.90% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 72,106
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [71/100] green_tripdata_2025-07.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2025-07.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2025-07.parquet
#   Raw rows   : 48,205, cols: 21
#   Clean rows : 47,296, cols: 20
#   Rows removed: 909 (1.89% removed, 98.11% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 79,315
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [72/100] green_tripdata_2025-08.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/green_tripdata_2025-08.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/green_tripdata_2025-08.parquet
#   Raw rows   : 46,306, cols: 21
#   Clean rows : 45,475, cols: 20
#   Rows removed: 831 (1.79% removed, 98.21% kept)
#   Dropped cols: ehail_fee
#   Nulls raw   : 74,759
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [73/100] yellow_tripdata_2009-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2009-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2009-02.parquet
#   Raw rows   : 13,380,122, cols: 18
#   Clean rows : 13,380,122, cols: 16
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: Rate_Code, mta_tax
#   Nulls raw   : 35,770,045
#   Nulls clean : 9,009,801
#   Null reduction: 74.81%  (major=True)
#
# [74/100] yellow_tripdata_2009-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2009-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2009-12.parquet
#   Raw rows   : 14,583,404, cols: 18
#   Clean rows : 14,583,404, cols: 17
#   Rows removed: 0 (0.00% removed, 100.00% kept)
#   Dropped cols: Rate_Code
#   Nulls raw   : 23,621,117
#   Nulls clean : 8,178,238
#   Null reduction: 65.38%  (major=True)
#
# [75/100] yellow_tripdata_2014-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2014-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2014-02.parquet
#   Raw rows   : 13,063,794, cols: 19
#   Clean rows : 13,063,681, cols: 17
#   Rows removed: 113 (0.00% removed, 100.00% kept)
#   Dropped cols: airport_fee, congestion_surcharge
#   Nulls raw   : 32,792,566
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [76/100] yellow_tripdata_2014-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2014-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2014-12.parquet
#   Raw rows   : 13,112,117, cols: 19
#   Clean rows : 13,105,964, cols: 17
#   Rows removed: 6,153 (0.05% removed, 99.95% kept)
#   Dropped cols: airport_fee, congestion_surcharge
#   Nulls raw   : 26,224,374
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [77/100] yellow_tripdata_2015-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2015-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2015-02.parquet
#   Raw rows   : 12,442,394, cols: 19
#   Clean rows : 12,429,977, cols: 17
#   Rows removed: 12,417 (0.10% removed, 99.90% kept)
#   Dropped cols: airport_fee, congestion_surcharge
#   Nulls raw   : 24,884,788
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [78/100] yellow_tripdata_2015-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2015-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2015-12.parquet
#   Raw rows   : 11,452,996, cols: 19
#   Clean rows : 11,447,795, cols: 17
#   Rows removed: 5,201 (0.05% removed, 99.95% kept)
#   Dropped cols: airport_fee, congestion_surcharge
#   Nulls raw   : 22,905,992
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [79/100] yellow_tripdata_2019-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2019-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2019-02.parquet
#   Raw rows   : 7,049,370, cols: 19
#   Clean rows : 6,920,741, cols: 18
#   Rows removed: 128,629 (1.82% removed, 98.18% kept)
#   Dropped cols: airport_fee
#   Nulls raw   : 7,168,022
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [80/100] yellow_tripdata_2019-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2019-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2019-12.parquet
#   Raw rows   : 6,896,317, cols: 19
#   Clean rows : 6,746,824, cols: 18
#   Rows removed: 149,493 (2.17% removed, 97.83% kept)
#   Dropped cols: airport_fee
#   Nulls raw   : 7,100,389
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [81/100] yellow_tripdata_2024-01.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-01.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-01.parquet
#   Raw rows   : 2,964,624, cols: 19
#   Clean rows : 2,895,631, cols: 19
#   Rows removed: 68,993 (2.33% removed, 97.67% kept)
#   Nulls raw   : 700,810
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [82/100] yellow_tripdata_2024-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-02.parquet
#   Raw rows   : 3,007,526, cols: 19
#   Clean rows : 2,932,683, cols: 19
#   Rows removed: 74,843 (2.49% removed, 97.51% kept)
#   Nulls raw   : 928,050
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [83/100] yellow_tripdata_2024-03.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-03.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-03.parquet
#   Raw rows   : 3,582,628, cols: 19
#   Clean rows : 3,483,658, cols: 19
#   Rows removed: 98,970 (2.76% removed, 97.24% kept)
#   Nulls raw   : 2,130,950
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [84/100] yellow_tripdata_2024-04.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-04.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-04.parquet
#   Raw rows   : 3,514,289, cols: 19
#   Clean rows : 3,416,960, cols: 19
#   Rows removed: 97,329 (2.77% removed, 97.23% kept)
#   Nulls raw   : 2,042,880
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [85/100] yellow_tripdata_2024-05.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-05.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-05.parquet
#   Raw rows   : 3,723,833, cols: 19
#   Clean rows : 3,623,970, cols: 19
#   Rows removed: 99,863 (2.68% removed, 97.32% kept)
#   Nulls raw   : 2,023,330
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [86/100] yellow_tripdata_2024-06.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-06.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-06.parquet
#   Raw rows   : 3,539,193, cols: 19
#   Clean rows : 3,441,506, cols: 19
#   Rows removed: 97,687 (2.76% removed, 97.24% kept)
#   Nulls raw   : 2,053,905
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [87/100] yellow_tripdata_2024-07.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-07.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-07.parquet
#   Raw rows   : 3,076,903, cols: 19
#   Clean rows : 2,988,953, cols: 19
#   Rows removed: 87,950 (2.86% removed, 97.14% kept)
#   Nulls raw   : 1,394,945
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [88/100] yellow_tripdata_2024-08.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-08.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-08.parquet
#   Raw rows   : 2,979,183, cols: 19
#   Clean rows : 2,894,471, cols: 19
#   Rows removed: 84,712 (2.84% removed, 97.16% kept)
#   Nulls raw   : 1,293,335
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [89/100] yellow_tripdata_2024-09.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-09.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-09.parquet
#   Raw rows   : 3,633,030, cols: 19
#   Clean rows : 3,529,402, cols: 19
#   Rows removed: 103,628 (2.85% removed, 97.15% kept)
#   Nulls raw   : 2,418,655
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [90/100] yellow_tripdata_2024-10.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-10.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-10.parquet
#   Raw rows   : 3,833,771, cols: 19
#   Clean rows : 3,722,475, cols: 19
#   Rows removed: 111,296 (2.90% removed, 97.10% kept)
#   Nulls raw   : 1,969,475
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [91/100] yellow_tripdata_2024-11.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-11.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-11.parquet
#   Raw rows   : 3,646,369, cols: 19
#   Clean rows : 3,546,370, cols: 19
#   Rows removed: 99,999 (2.74% removed, 97.26% kept)
#   Nulls raw   : 1,868,370
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [92/100] yellow_tripdata_2024-12.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2024-12.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2024-12.parquet
#   Raw rows   : 3,668,371, cols: 19
#   Clean rows : 3,559,383, cols: 19
#   Rows removed: 108,988 (2.97% removed, 97.03% kept)
#   Nulls raw   : 1,631,455
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [93/100] yellow_tripdata_2025-01.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2025-01.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2025-01.parquet
#   Raw rows   : 3,475,226, cols: 20
#   Clean rows : 3,306,273, cols: 20
#   Rows removed: 168,953 (4.86% removed, 95.14% kept)
#   Nulls raw   : 2,700,745
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [94/100] yellow_tripdata_2025-02.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2025-02.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2025-02.parquet
#   Raw rows   : 3,577,543, cols: 20
#   Clean rows : 3,372,961, cols: 20
#   Rows removed: 204,582 (5.72% removed, 94.28% kept)
#   Nulls raw   : 4,034,685
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [95/100] yellow_tripdata_2025-03.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2025-03.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2025-03.parquet
#   Raw rows   : 4,145,257, cols: 20
#   Clean rows : 3,913,606, cols: 20
#   Rows removed: 231,651 (5.59% removed, 94.41% kept)
#   Nulls raw   : 4,583,315
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [96/100] yellow_tripdata_2025-04.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2025-04.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2025-04.parquet
#   Raw rows   : 3,970,553, cols: 20
#   Clean rows : 3,760,427, cols: 20
#   Rows removed: 210,126 (5.29% removed, 94.71% kept)
#   Nulls raw   : 3,728,650
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [97/100] yellow_tripdata_2025-05.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2025-05.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2025-05.parquet
#   Raw rows   : 4,591,845, cols: 20
#   Clean rows : 4,242,250, cols: 20
#   Rows removed: 349,595 (7.61% removed, 92.39% kept)
#   Nulls raw   : 5,980,880
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [98/100] yellow_tripdata_2025-06.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2025-06.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2025-06.parquet
#   Raw rows   : 4,322,960, cols: 20
#   Clean rows : 4,024,343, cols: 20
#   Rows removed: 298,617 (6.91% removed, 93.09% kept)
#   Nulls raw   : 6,064,730
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [99/100] yellow_tripdata_2025-07.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2025-07.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2025-07.parquet
#   Raw rows   : 3,898,963, cols: 20
#   Clean rows : 3,631,053, cols: 20
#   Rows removed: 267,910 (6.87% removed, 93.13% kept)
#   Nulls raw   : 5,193,775
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# [100/100] yellow_tripdata_2025-08.parquet
#   Raw path   : /Users/vidushi/Documents/bubu/Raw_data/raw_data/yellow_tripdata_2025-08.parquet
#   Clean path : /Users/vidushi/Documents/bubu/cleaned_data/yellow_tripdata_2025-08.parquet
#   Raw rows   : 3,574,091, cols: 20
#   Clean rows : 3,295,362, cols: 20
#   Rows removed: 278,729 (7.80% removed, 92.20% kept)
#   Nulls raw   : 4,431,170
#   Nulls clean : 0
#   Null reduction: 100.00%  (major=True)
#
# Summary (first 10 files):
#                            File  Raw Rows  Clean Rows  Raw - Clean  cleaned %  \
# 0  fhv_tripdata_2015-02.parquet   3053183     3053183            0      100.0
# 1  fhv_tripdata_2015-12.parquet   8888809     8888809            0      100.0
# 2  fhv_tripdata_2019-02.parquet   1707650     1707650            0      100.0
# 3  fhv_tripdata_2019-12.parquet   2044196     2044196            0      100.0
# 4  fhv_tripdata_2024-01.parquet   1290116     1290116            0      100.0
# 5  fhv_tripdata_2024-02.parquet   1176093     1176093            0      100.0
# 6  fhv_tripdata_2024-03.parquet   1469352     1469352            0      100.0
# 7  fhv_tripdata_2024-04.parquet   1444626     1444626            0      100.0
# 8  fhv_tripdata_2024-05.parquet   1352502     1352502            0      100.0
# 9  fhv_tripdata_2024-06.parquet   1386539     1386539            0      100.0
#
#    removed %  Raw Cols  Clean Cols Dropped Cols Added Cols  \
# 0        0.0         7           6      SR_Flag
# 1        0.0         7           6      SR_Flag
# 2        0.0         7           7
# 3        0.0         7           6      SR_Flag
# 4        0.0         7           6      SR_Flag
# 5        0.0         7           6      SR_Flag
# 6        0.0         7           6      SR_Flag
# 7        0.0         7           6      SR_Flag
# 8        0.0         7           6      SR_Flag
# 9        0.0         7           6      SR_Flag
#
#    Major Null Reduction
# 0                  True
# 1                  True
# 2                 False
# 3                  True
# 4                  True
# 5                  True
# 6                  True
# 7                  True
# 8                  True
# 9                  True

# %%
# Save full summary to CSV for Excel / further analysis

output_path = Path("clean_vs_raw_summary.csv")
summary_df.to_csv(output_path, index=False)

print("\nSaved compact summary to:", output_path)
summary_df
# Out:
# Saved compact summary to: clean_vs_raw_summary.csv
#                                File  Raw Rows  Clean Rows  Raw - Clean  \
# 0      fhv_tripdata_2015-02.parquet   3053183     3053183            0
# 1      fhv_tripdata_2015-12.parquet   8888809     8888809            0
# 2      fhv_tripdata_2019-02.parquet   1707650     1707650            0
# 3      fhv_tripdata_2019-12.parquet   2044196     2044196            0
# 4      fhv_tripdata_2024-01.parquet   1290116     1290116            0
# ..                              ...       ...         ...          ...
# 95  yellow_tripdata_2025-04.parquet   3970553     3760427       210126
# 96  yellow_tripdata_2025-05.parquet   4591845     4242250       349595
# 97  yellow_tripdata_2025-06.parquet   4322960     4024343       298617
# 98  yellow_tripdata_2025-07.parquet   3898963     3631053       267910
# 99  yellow_tripdata_2025-08.parquet   3574091     3295362       278729
#
#     cleaned %  removed %  Raw Cols  Clean Cols Dropped Cols Added Cols  \
# 0      100.00       0.00         7           6      SR_Flag
# 1      100.00       0.00         7           6      SR_Flag
# 2      100.00       0.00         7           7
# 3      100.00       0.00         7           6      SR_Flag
# 4      100.00       0.00         7           6      SR_Flag
# ..        ...        ...       ...         ...          ...        ...
# 95      94.71       5.29        20          20
# 96      92.39       7.61        20          20
# 97      93.09       6.91        20          20
# 98      93.13       6.87        20          20
# 99      92.20       7.80        20          20
#
#     Major Null Reduction
# 0                   True
# 1                   True
# 2                  False
# 3                   True
# 4                   True
# ..                   ...
# 95                  True
# 96                  True
# 97                  True
# 98                  True
# 99                  True
#
# [100 rows x 11 columns]
